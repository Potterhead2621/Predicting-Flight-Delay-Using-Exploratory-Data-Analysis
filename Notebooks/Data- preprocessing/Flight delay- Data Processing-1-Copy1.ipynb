# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\asus\anaconda3\lib\site-packages (1.4.4)Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -cipy (c:\users\asus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\asus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\asus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\asus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\asus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\asus\anaconda3\lib\site-packages)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\asus\anaconda3\lib\site-packages (from pandas) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\asus\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asus\anaconda3\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\asus\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
pd.set_option('display.max_columns', None)
import datetime, warnings, scipy
warnings.filterwarnings("ignore")

# %%
df1 = pd.read_csv("C:/Users/Asus/Downloads/Flight delay dataset/Flight-Delay-Prediction/Combined_Flights_2022.csv")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4078318 entries, 0 to 4078317
# Data columns (total 61 columns):
#  #   Column                                   Dtype
# ---  ------                                   -----
#  0   FlightDate                               object
#  1   Airline                                  object
#  2   Origin                                   object
#  3   Dest                                     object
#  4   Cancelled                                bool
#  5   Diverted                                 bool
#  6   CRSDepTime                               int64
#  7   DepTime                                  float64
#  8   DepDelayMinutes                          float64
#  9   DepDelay                                 float64
#  10  ArrTime                                  float64
#  11  ArrDelayMinutes                          float64
#  12  AirTime                                  float64
#  13  CRSElapsedTime                           float64
#  14  ActualElapsedTime                        float64
#  15  Distance                                 float64
#  16  Year                                     int64
#  17  Quarter                                  int64
#  18  Month                                    int64
#  19  DayofMonth                               int64
#  20  DayOfWeek                                int64
#  21  Marketing_Airline_Network                object
#  22  Operated_or_Branded_Code_Share_Partners  object
#  23  DOT_ID_Marketing_Airline                 int64
#  24  IATA_Code_Marketing_Airline              object
#  25  Flight_Number_Marketing_Airline          int64
#  26  Operating_Airline                        object
#  27  DOT_ID_Operating_Airline                 int64
#  28  IATA_Code_Operating_Airline              object
#  29  Tail_Number                              object
#  30  Flight_Number_Operating_Airline          int64
#  31  OriginAirportID                          int64
#  32  OriginAirportSeqID                       int64
#  33  OriginCityMarketID                       int64
#  34  OriginCityName                           object
#  35  OriginState                              object
#  36  OriginStateFips                          int64
#  37  OriginStateName                          object
#  38  OriginWac                                int64
#  39  DestAirportID                            int64
#  40  DestAirportSeqID                         int64
#  41  DestCityMarketID                         int64
#  42  DestCityName                             object
#  43  DestState                                object
#  44  DestStateFips                            int64
#  45  DestStateName                            object
#  46  DestWac                                  int64
#  47  DepDel15                                 float64
#  48  DepartureDelayGroups                     float64
#  49  DepTimeBlk                               object
#  50  TaxiOut                                  float64
#  51  WheelsOff                                float64
#  52  WheelsOn                                 float64
#  53  TaxiIn                                   float64
#  54  CRSArrTime                               int64
#  55  ArrDelay                                 float64
#  56  ArrDel15                                 float64
#  57  ArrivalDelayGroups                       float64
#  58  ArrTimeBlk                               object
#  59  DistanceGroup                            int64
#  60  DivAirportLandings                       int64
# dtypes: bool(2), float64(18), int64(23), object(18)
# memory usage: 1.8+ GB

# %%
df1.shape
# Out:
# (4078318, 61)

# %%
df1.Marketing_Airline_Network.unique()
# Out:
# array(['UA', 'WN', 'AA', 'DL', 'AS', 'B6', 'F9', 'G4', 'HA', 'NK'],
#       dtype=object)

# %%
df1.Operating_Airline.unique()
# Out:
# array(['C5', 'G7', 'ZW', 'YV', 'WN', 'YX', '9E', 'AA', 'PT', 'OO', 'AS',
#        'B6', 'DL', 'F9', 'G4', 'HA', 'MQ', 'NK', 'OH', 'QX', 'UA'],
#       dtype=object)

# %%
df1['Operating_Airline'].replace({
    'UA':'United Airlines',
    'AS':'Alaska Airlines',
    '9E':'Endeavor Air',
    'B6':'JetBlue Airways',
    'C5':'CommutAir',
    'G7':'GoJet Airlines',
    'ZW':'Air Wisconsin',
    'PT':'Piedmont Airlines',
    'QX':'Horizon Air',
    'F9':'Frontier Airlines',
    'G4':'Allegiant Air',
    'HA':'Hawaiian Airlines',
    'MQ':'Envoy Air',
    'NK':'Spirit Airlines',
    'OH':'PSA Airlines',
    'OO':'SkyWest Airlines',
    'WN':'Southwest Airlines',
    'YV':'Mesa Airline',
    'YX':'Republic Airways',
    'AA':'American Airlines',
    'DL':'Delta Airlines'
}, inplace=True)

# %%
df1.Operating_Airline.value_counts()
# Out:
# Southwest Airlines    731925
# Delta Airlines        512114
# American Airlines     495953
# SkyWest Airlines      440807
# United Airlines       352009
# Republic Airways      197881
# JetBlue Airways       156793
# Envoy Air             150758
# Endeavor Air          142624
# PSA Airlines          135884
# Alaska Airlines       129510
# Spirit Airlines       129208
# Frontier Airlines      86557
# Allegiant Air          73504
# Mesa Airline           71972
# Horizon Air            56320
# Piedmont Airlines      52827
# CommutAir              44367
# Hawaiian Airlines      42212
# Air Wisconsin          40300
# GoJet Airlines         34793
# Name: Operating_Airline, dtype: int64

# %%
df1.Cancelled.nunique()
# Out:
# 2

# %%
df1.Cancelled.value_counts()
# Out:
# False    3955126
# True      123192
# Name: Cancelled, dtype: int64

# %%
df1['Cancelled'].replace({
    'True':1,
    'False':0
}, inplace=True)

# %%
df1.Cancelled.value_counts()
# Out:
# False    3955126
# True      123192
# Name: Cancelled, dtype: int64

# %%
dummy = df1[(df1['Cancelled'] == 1)]
print('dummy shape:', dummy.shape)
print('====================================')
print('dummy dataframe:')
dummy.head(3).append(dummy.tail(3))
# Out:
# dummy shape: (123192, 61)
# ====================================
# dummy dataframe:
#          FlightDate                                    Airline Origin Dest  \
# 949      2022-04-02  Commutair Aka Champlain Enterprises, Inc.    JAX  IAH
# 970      2022-04-02  Commutair Aka Champlain Enterprises, Inc.    IAH  JAX
# 982      2022-04-02  Commutair Aka Champlain Enterprises, Inc.    IAH  ECP
# 4078234  2022-03-02                          Republic Airlines    RDU  EWR
# 4078311  2022-03-31                          Republic Airlines    EWR  PIT
# 4078314  2022-03-17                          Republic Airlines    CLT  EWR
#
#          Cancelled  Diverted  CRSDepTime  DepTime  DepDelayMinutes  DepDelay  \
# 949           True     False        1842      NaN              NaN       NaN
# 970           True     False        1435      NaN              NaN       NaN
# 982           True     False        1426      NaN              NaN       NaN
# 4078234       True     False        1430    957.0           1167.0    1167.0
# 4078311       True     False        1829   2033.0            124.0     124.0
# 4078314       True     False        1733   1817.0             44.0      44.0
#
#          ArrTime  ArrDelayMinutes  AirTime  CRSElapsedTime  ActualElapsedTime  \
# 949          NaN              NaN      NaN           169.0                NaN
# 970          NaN              NaN      NaN           142.0                NaN
# 982          NaN              NaN      NaN           105.0                NaN
# 4078234      NaN              NaN      NaN           113.0                NaN
# 4078311      NaN              NaN      NaN            97.0                NaN
# 4078314      NaN              NaN      NaN           129.0                NaN
#
#          Distance  Year  Quarter  Month  DayofMonth  DayOfWeek  \
# 949         817.0  2022        2      4           2          6
# 970         817.0  2022        2      4           2          6
# 982         572.0  2022        2      4           2          6
# 4078234     416.0  2022        1      3           2          3
# 4078311     319.0  2022        1      3          31          4
# 4078314     529.0  2022        1      3          17          4
#
#         Marketing_Airline_Network Operated_or_Branded_Code_Share_Partners  \
# 949                            UA                            UA_CODESHARE
# 970                            UA                            UA_CODESHARE
# 982                            UA                            UA_CODESHARE
# 4078234                        UA                            UA_CODESHARE
# 4078311                        UA                            UA_CODESHARE
# 4078314                        UA                            UA_CODESHARE
#
#          DOT_ID_Marketing_Airline IATA_Code_Marketing_Airline  \
# 949                         19977                          UA
# 970                         19977                          UA
# 982                         19977                          UA
# 4078234                     19977                          UA
# 4078311                     19977                          UA
# 4078314                     19977                          UA
#
#          Flight_Number_Marketing_Airline Operating_Airline  \
# 949                                 4358         CommutAir
# 970                                 4334         CommutAir
# 982                                 4321         CommutAir
# 4078234                             3438  Republic Airways
# 4078311                             3687  Republic Airways
# 4078314                             3437  Republic Airways
#
#          DOT_ID_Operating_Airline IATA_Code_Operating_Airline Tail_Number  \
# 949                         20445                          C5         NaN
# 970                         20445                          C5         NaN
# 982                         20445                          C5         NaN
# 4078234                     20452                          YX      N856RW
# 4078311                     20452                          YX      N651RW
# 4078314                     20452                          YX      N654RW
#
#          Flight_Number_Operating_Airline  OriginAirportID  OriginAirportSeqID  \
# 949                                 4358            12451             1245102
# 970                                 4334            12266             1226603
# 982                                 4321            12266             1226603
# 4078234                             3438            14492             1449202
# 4078311                             3687            11618             1161802
# 4078314                             3437            11057             1105703
#
#          OriginCityMarketID      OriginCityName OriginState  OriginStateFips  \
# 949                   31136    Jacksonville, FL          FL               12
# 970                   31453         Houston, TX          TX               48
# 982                   31453         Houston, TX          TX               48
# 4078234               34492  Raleigh/Durham, NC          NC               37
# 4078311               31703          Newark, NJ          NJ               34
# 4078314               31057       Charlotte, NC          NC               37
#
#         OriginStateName  OriginWac  DestAirportID  DestAirportSeqID  \
# 949             Florida         33          12266           1226603
# 970               Texas         74          12451           1245102
# 982               Texas         74          11481           1148102
# 4078234  North Carolina         36          11618           1161802
# 4078311      New Jersey         21          14122           1412202
# 4078314  North Carolina         36          11618           1161802
#
#          DestCityMarketID      DestCityName DestState  DestStateFips  \
# 949                 31453       Houston, TX        TX             48
# 970                 31136  Jacksonville, FL        FL             12
# 982                 31481   Panama City, FL        FL             12
# 4078234             31703        Newark, NJ        NJ             34
# 4078311             30198    Pittsburgh, PA        PA             42
# 4078314             31703        Newark, NJ        NJ             34
#
#         DestStateName  DestWac  DepDel15  DepartureDelayGroups DepTimeBlk  \
# 949             Texas       74       NaN                   NaN  1800-1859
# 970           Florida       33       NaN                   NaN  1400-1459
# 982           Florida       33       NaN                   NaN  1400-1459
# 4078234    New Jersey       21       1.0                  12.0  1400-1459
# 4078311  Pennsylvania       23       1.0                   8.0  1800-1859
# 4078314    New Jersey       21       1.0                   2.0  1700-1759
#
#          TaxiOut  WheelsOff  WheelsOn  TaxiIn  CRSArrTime  ArrDelay  ArrDel15  \
# 949          NaN        NaN       NaN     NaN        2031       NaN       NaN
# 970          NaN        NaN       NaN     NaN        1757       NaN       NaN
# 982          NaN        NaN       NaN     NaN        1611       NaN       NaN
# 4078234      NaN        NaN       NaN     NaN        1623       NaN       NaN
# 4078311      NaN        NaN       NaN     NaN        2006       NaN       NaN
# 4078314      NaN        NaN       NaN     NaN        1942       NaN       NaN
#
#          ArrivalDelayGroups ArrTimeBlk  DistanceGroup  DivAirportLandings
# 949                     NaN  2000-2059              4                   0
# 970                     NaN  1700-1759              4                   0
# 982                     NaN  1600-1659              3                   0
# 4078234                 NaN  1600-1659              2                   0
# 4078311                 NaN  2000-2059              2                   0
# 4078314                 NaN  1900-1959              3                   0

# %%
dummy.Cancelled.nunique()
# Out:
# 1

# %%
dummy.Cancelled.value_counts()
# Out:
# True    123192
# Name: Cancelled, dtype: int64

# %%
df1 = df1[(df1['Cancelled'] == 0)]
df1.head(2)
# Out:
#    FlightDate                                    Airline Origin Dest  \
# 0  2022-04-04  Commutair Aka Champlain Enterprises, Inc.    GJT  DEN
# 1  2022-04-04  Commutair Aka Champlain Enterprises, Inc.    HRL  IAH
#
#    Cancelled  Diverted  CRSDepTime  DepTime  DepDelayMinutes  DepDelay  \
# 0      False     False        1133   1123.0              0.0     -10.0
# 1      False     False         732    728.0              0.0      -4.0
#
#    ArrTime  ArrDelayMinutes  AirTime  CRSElapsedTime  ActualElapsedTime  \
# 0   1228.0              0.0     40.0            72.0               65.0
# 1    848.0              0.0     55.0            77.0               80.0
#
#    Distance  Year  Quarter  Month  DayofMonth  DayOfWeek  \
# 0     212.0  2022        2      4           4          1
# 1     295.0  2022        2      4           4          1
#
#   Marketing_Airline_Network Operated_or_Branded_Code_Share_Partners  \
# 0                        UA                            UA_CODESHARE
# 1                        UA                            UA_CODESHARE
#
#    DOT_ID_Marketing_Airline IATA_Code_Marketing_Airline  \
# 0                     19977                          UA
# 1                     19977                          UA
#
#    Flight_Number_Marketing_Airline Operating_Airline  \
# 0                             4301         CommutAir
# 1                             4299         CommutAir
#
#    DOT_ID_Operating_Airline IATA_Code_Operating_Airline Tail_Number  \
# 0                     20445                          C5      N21144
# 1                     20445                          C5      N16170
#
#    Flight_Number_Operating_Airline  OriginAirportID  OriginAirportSeqID  \
# 0                             4301            11921             1192102
# 1                             4299            12206             1220605
#
#    OriginCityMarketID            OriginCityName OriginState  OriginStateFips  \
# 0               31921        Grand Junction, CO          CO                8
# 1               32206  Harlingen/San Benito, TX          TX               48
#
#   OriginStateName  OriginWac  DestAirportID  DestAirportSeqID  \
# 0        Colorado         82          11292           1129202
# 1           Texas         74          12266           1226603
#
#    DestCityMarketID DestCityName DestState  DestStateFips DestStateName  \
# 0             30325   Denver, CO        CO              8      Colorado
# 1             31453  Houston, TX        TX             48         Texas
#
#    DestWac  DepDel15  DepartureDelayGroups DepTimeBlk  TaxiOut  WheelsOff  \
# 0       82       0.0                  -1.0  1100-1159     17.0     1140.0
# 1       74       0.0                  -1.0  0700-0759     16.0      744.0
#
#    WheelsOn  TaxiIn  CRSArrTime  ArrDelay  ArrDel15  ArrivalDelayGroups  \
# 0    1220.0     8.0        1245     -17.0       0.0                -2.0
# 1     839.0     9.0         849      -1.0       0.0                -1.0
#
#   ArrTimeBlk  DistanceGroup  DivAirportLandings
# 0  1200-1259              1                   0
# 1  0800-0859              2                   0

# %%
df1 = df1.drop(['Cancelled'], axis = 1)

# %%
df1.shape
# Out:
# (3955126, 60)

# %%
airports = pd.read_csv('C:/Users/Asus/Downloads/airports.csv')
airports.head(10)
# Out:
#   IATA_CODE                              AIRPORT           CITY STATE COUNTRY  \
# 0       ABE  Lehigh Valley International Airport      Allentown    PA     USA
# 1       ABI             Abilene Regional Airport        Abilene    TX     USA
# 2       ABQ    Albuquerque International Sunport    Albuquerque    NM     USA
# 3       ABR            Aberdeen Regional Airport       Aberdeen    SD     USA
# 4       ABY   Southwest Georgia Regional Airport         Albany    GA     USA
# 5       ACK           Nantucket Memorial Airport      Nantucket    MA     USA
# 6       ACT                Waco Regional Airport           Waco    TX     USA
# 7       ACV                       Arcata Airport  Arcata/Eureka    CA     USA
# 8       ACY  Atlantic City International Airport  Atlantic City    NJ     USA
# 9       ADK                         Adak Airport           Adak    AK     USA
#
#    LATITUDE  LONGITUDE
# 0  40.65236  -75.44040
# 1  32.41132  -99.68190
# 2  35.04022 -106.60919
# 3  45.44906  -98.42183
# 4  31.53552  -84.19447
# 5  41.25305  -70.06018
# 6  31.61129  -97.23052
# 7  40.97812 -124.10862
# 8  39.45758  -74.57717
# 9  51.87796 -176.64603

# %%
airports.shape
# Out:
# (322, 7)

# %%
len(airports.IATA_CODE.unique())
# Out:
# 322

# %%
airport_IATA_CODE = list(airports['IATA_CODE'])

# %%
len(airport_IATA_CODE)
# Out:
# 322

# %%
df1.Origin.unique()
# Out:
# array(['GJT', 'HRL', 'DRO', 'IAH', 'DEN', 'TYS', 'MOB', 'LNK', 'BHM',
#        'IAD', 'ECP', 'AEX', 'LFT', 'BTR', 'ABQ', 'BUF', 'ALB', 'HSV',
#        'TUL', 'CPR', 'CRP', 'EWR', 'DCA', 'STL', 'CVG', 'RIC', 'PVD',
#        'CLT', 'GSO', 'ERI', 'ORD', 'LEX', 'ABE', 'CAK', 'AVL', 'DAY',
#        'CHO', 'ROA', 'PWM', 'LIT', 'MKE', 'BTV', 'OMA', 'GRB', 'MLI',
#        'SDF', 'FNT', 'CHS', 'PIT', 'TVC', 'ATW', 'DLH', 'ROC', 'SPI',
#        'HPN', 'MBS', 'CID', 'MYR', 'CAE', 'SGF', 'AVP', 'GRR', 'DSM',
#        'CLE', 'PIA', 'MSN', 'MDT', 'SBN', 'MEM', 'ICT', 'SHV', 'XNA',
#        'DIK', 'GPT', 'PNS', 'LRD', 'LCH', 'MFE', 'FLG', 'BRO', 'SAF',
#        'PQI', 'ORF', 'LGA', 'SYR', 'RDU', 'ILM', 'IND', 'PHL', 'CMH',
#        'SCE', 'ITH', 'JAX', 'OKC', 'JAN', 'GSP', 'TXK', 'ELP', 'MAF',
#        'AUS', 'IDA', 'BNA', 'SAV', 'AMA', 'ATL', 'BDL', 'BLI', 'BOI',
#        'BOS', 'BUR', 'BWI', 'BZN', 'COS', 'DAL', 'DTW', 'EUG', 'FAT',
#        'FLL', 'GEG', 'HDN', 'HNL', 'HOU', 'ISP', 'ITO', 'KOA', 'LAS',
#        'LAX', 'LBB', 'LGB', 'LIH', 'MCI', 'MCO', 'MDW', 'MHT', 'MIA',
#        'MSP', 'MSY', 'MTJ', 'OAK', 'OGG', 'ONT', 'PBI', 'PDX', 'PHX',
#        'PSP', 'RNO', 'RSW', 'SAN', 'SAT', 'SBA', 'SEA', 'SFO', 'SJC',
#        'SJU', 'SLC', 'SMF', 'SNA', 'SRQ', 'TPA', 'TUS', 'VPS', 'DFW',
#        'HHH', 'BFL', 'FAR', 'YUM', 'FSD', 'MRY', 'BMI', 'RAP', 'DAB',
#        'FAY', 'GNV', 'MGM', 'STS', 'TLH', 'MFR', 'JFK', 'AGS', 'EYW',
#        'ORH', 'BGR', 'CHA', 'CRW', 'BQK', 'OAJ', 'LAN', 'AZO', 'DHN',
#        'TRI', 'BIS', 'VLD', 'ABY', 'GTR', 'MLU', 'MOT', 'RST', 'CWA',
#        'CSG', 'EVV', 'GFK', 'FWA', 'BGM', 'STT', 'EGE', 'JAC', 'MSO',
#        'STX', 'GUC', 'PHF', 'PGV', 'ART', 'HTS', 'LYH', 'FLO', 'SBY',
#        'ADQ', 'ANC', 'BET', 'BRW', 'JNU', 'KTN', 'CDV', 'YAK', 'FAI',
#        'PSG', 'WRG', 'SIT', 'OME', 'OTZ', 'PAE', 'ADK', 'SCC', 'BQN',
#        'PSE', 'BIL', 'FCA', 'MLB', 'ILG', 'TTN', 'SWF', 'USA', 'SFB',
#        'PIE', 'AZA', 'RFD', 'GRI', 'PBG', 'PGD', 'PVU', 'TOL', 'BLV',
#        'LCK', 'ELM', 'PSM', 'SCK', 'IAG', 'PSC', 'CKB', 'STC', 'HGR',
#        'OWB', 'SMX', 'GTF', 'RDM', 'OGD', 'PPG', 'GCK', 'ACT', 'ALO',
#        'LAW', 'GGG', 'COU', 'SPS', 'ABI', 'CMI', 'DRT', 'FSM', 'LSE',
#        'TYR', 'GRK', 'DBQ', 'BPT', 'MHK', 'SJT', 'SWO', 'MQT', 'SBP',
#        'CLL', 'ACY', 'LBE', 'EWN', 'ROW', 'SGU', 'ACV', 'ASE', 'XWA',
#        'HLN', 'OTH', 'SLN', 'LWS', 'HOB', 'HYS', 'ALS', 'CNY', 'RKS',
#        'DVL', 'JMS', 'PAH', 'PRC', 'RIW', 'BFF', 'DDC', 'SUX', 'CMX',
#        'MEI', 'JLN', 'EAU', 'GCC', 'SHR', 'TBN', 'FOD', 'LAR', 'VEL',
#        'OGS', 'PUB', 'VCT', 'DEC', 'CYS', 'LBF', 'JST', 'MCW', 'RDD',
#        'SHD', 'CGI', 'EAR', 'MKG', 'LWB', 'LBL', 'COD', 'PIB', 'BTM',
#        'SUN', 'IMT', 'RHI', 'ESC', 'APN', 'ABR', 'PLN', 'INL', 'BRD',
#        'HIB', 'CIU', 'PIH', 'TWF', 'EKO', 'BJI', 'CDC', 'YKM', 'PUW',
#        'ALW', 'EAT', 'DLG', 'AKN', 'GUM', 'SPN', 'BIH', 'WYS', 'ACK',
#        'BKG', 'GST', 'MVY', 'HYA', 'PIR', 'ATY'], dtype=object)

# %%
df1_ORIGIN = df1.Origin.unique()
df1_DEST = df1.Dest.unique()

# %%
print(type(df1_ORIGIN))
print(type(df1_DEST))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
df1_ORIGIN = df1_ORIGIN.tolist()
df1_DEST = df1_DEST.tolist()

# %%
print(type(df1_ORIGIN))
print(type(df1_DEST))
# Out:
# <class 'list'>
# <class 'list'>

# %%
print(len(df1_ORIGIN))
print(len(df1_DEST))
# Out:
# 375
# 375

# %%
difference_1 = [item for item in airport_IATA_CODE if item not in df1_ORIGIN]
difference_1
# Out:
# ['CEC', 'CLD', 'ISN', 'MMH', 'UST']

# %%
difference_2 = [item for item in df1_ORIGIN if item not in airport_IATA_CODE]
difference_2
# Out:
# ['PQI',
#  'HHH',
#  'STS',
#  'PGV',
#  'ART',
#  'HTS',
#  'LYH',
#  'FLO',
#  'SBY',
#  'PAE',
#  'USA',
#  'SFB',
#  'PIE',
#  'AZA',
#  'RFD',
#  'PGD',
#  'PVU',
#  'BLV',
#  'LCK',
#  'PSM',
#  'SCK',
#  'CKB',
#  'HGR',
#  'OWB',
#  'OGD',
#  'DRT',
#  'SWO',
#  'XWA',
#  'SLN',
#  'ALS',
#  'PRC',
#  'RIW',
#  'BFF',
#  'DDC',
#  'SHR',
#  'TBN',
#  'FOD',
#  'OGS',
#  'VCT',
#  'DEC',
#  'CYS',
#  'LBF',
#  'JST',
#  'MCW',
#  'SHD',
#  'CGI',
#  'EAR',
#  'LWB',
#  'LBL',
#  'YKM',
#  'PUW',
#  'ALW',
#  'EAT',
#  'SPN',
#  'BIH',
#  'BKG',
#  'PIR',
#  'ATY']

# %%
len(difference_2)
# Out:
# 58

# %%
difference_3 = [item for item in df1_DEST if item not in airport_IATA_CODE]
difference_4 = [item for item in airport_IATA_CODE if item not in df1_DEST]
print(type(difference_3))
print(type(difference_4))
# Out:
# <class 'list'>
# <class 'list'>

# %%
print(difference_1)
print(difference_4)
# Out:
# ['CEC', 'CLD', 'ISN', 'MMH', 'UST']
# ['CEC', 'CLD', 'ISN', 'MMH', 'UST']

# %%
difference_2_3 = [item for item in difference_2 if item not in difference_3]
difference_2_3
# Out:
# []

# %%
missing_airports = pd.DataFrame(difference_2, columns=['IATA_CODE'])
print('missing_airports type is:', type(missing_airports))
print('===============================================================')
print('Dataframe difference_2 shape:', missing_airports.shape)
print('===============================================================')
missing_airports.head(3).append(missing_airports.tail(3))
# Out:
# missing_airports type is: <class 'pandas.core.frame.DataFrame'>
# ===============================================================
# Dataframe difference_2 shape: (58, 1)
# ===============================================================
#    IATA_CODE
# 0        PQI
# 1        HHH
# 2        STS
# 55       BKG
# 56       PIR
# 57       ATY

# %%
missing_airports.to_csv('missing_airports.csv')

# %%
pip install openpyxl --upgrade --pre
# Out:
# Requirement already up-to-date: openpyxl in c:\users\asus\anaconda3\lib\site-packages (3.0.10)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied, skipping upgrade: et-xmlfile in c:\users\asus\anaconda3\lib\site-packages (from openpyxl) (1.0.1)

# %%
missing_airports = pd.read_csv('C:/Users/Asus/Downloads/Flight delay dataset/missing_airports.csv', index_col=0)
print(missing_airports.shape)
missing_airports.head(3).append(missing_airports.tail(2))
# Out:
# (58, 1)
#    IATA_CODE
# 0        PQI
# 1        HHH
# 2        STS
# 56       PIR
# 57       ATY

# %%
print(airports.shape)
airports.head(3)
# Out:
# (322, 7)
#   IATA_CODE                              AIRPORT         CITY STATE COUNTRY  \
# 0       ABE  Lehigh Valley International Airport    Allentown    PA     USA
# 1       ABI             Abilene Regional Airport      Abilene    TX     USA
# 2       ABQ    Albuquerque International Sunport  Albuquerque    NM     USA
#
#    LATITUDE  LONGITUDE
# 0  40.65236  -75.44040
# 1  32.41132  -99.68190
# 2  35.04022 -106.60919

# %%
airports = airports[airports.IATA_CODE != 'CEC']
airports = airports[airports.IATA_CODE != 'CLD']
airports = airports[airports.IATA_CODE != 'ISN']
airports = airports[airports.IATA_CODE != 'MMH']
airports = airports[airports.IATA_CODE != 'UST']

# %%
airports.shape
# Out:
# (317, 7)

# %%
AIRPORTS = airports.append(missing_airports, ignore_index=True)
AIRPORTS.shape
# Out:
# (375, 7)

# %%
AIRPORTS.head(2).append(AIRPORTS.tail(2))
# Out:
#     IATA_CODE                              AIRPORT       CITY STATE COUNTRY  \
# 0         ABE  Lehigh Valley International Airport  Allentown    PA     USA
# 1         ABI             Abilene Regional Airport    Abilene    TX     USA
# 373       PIR                                  NaN        NaN   NaN     NaN
# 374       ATY                                  NaN        NaN   NaN     NaN
#
#      LATITUDE  LONGITUDE
# 0    40.65236   -75.4404
# 1    32.41132   -99.6819
# 373       NaN        NaN
# 374       NaN        NaN

# %%
print('Number of cities with at least one airport:', AIRPORTS.CITY.nunique())
print('================================================')
print('Total number of airports:', AIRPORTS.IATA_CODE.nunique())
print('================================================')
# Out:
# Number of cities with at least one airport: 304
# ================================================
# Total number of airports: 375
# ================================================

# %%
airport_dict = pd.Series(AIRPORTS.CITY.values, index=AIRPORTS.IATA_CODE).to_dict()
print(type(airport_dict))
# Out:
# <class 'dict'>

# %%
df1['Origin'].replace(airport_dict, inplace=True)
df1['Dest'].replace(airport_dict, inplace=True)
df1.head(3).append(df1.tail(3))
# Out:
#          FlightDate                                    Airline  \
# 0        2022-04-04  Commutair Aka Champlain Enterprises, Inc.
# 1        2022-04-04  Commutair Aka Champlain Enterprises, Inc.
# 2        2022-04-04  Commutair Aka Champlain Enterprises, Inc.
# 4078315  2022-03-08                          Republic Airlines
# 4078316  2022-03-25                          Republic Airlines
# 4078317  2022-03-07                          Republic Airlines
#
#                  Origin        Dest  Diverted  CRSDepTime  DepTime  \
# 0        Grand Junction      Denver     False        1133   1123.0
# 1             Harlingen     Houston     False         732    728.0
# 2               Durango      Denver     False        1529   1514.0
# 4078315          Albany     Chicago     False        1700   2318.0
# 4078316          Newark  Pittsburgh      True        2129   2322.0
# 4078317          Newark     Raleigh      True        1154   1148.0
#
#          DepDelayMinutes  DepDelay  ArrTime  ArrDelayMinutes  AirTime  \
# 0                    0.0     -10.0   1228.0              0.0     40.0
# 1                    0.0      -4.0    848.0              0.0     55.0
# 2                    0.0     -15.0   1636.0              0.0     47.0
# 4078315            378.0     378.0     59.0            381.0    135.0
# 4078316            113.0     113.0    939.0              NaN      NaN
# 4078317              0.0      -6.0   1556.0              NaN      NaN
#
#          CRSElapsedTime  ActualElapsedTime  Distance  Year  Quarter  Month  \
# 0                  72.0               65.0     212.0  2022        2      4
# 1                  77.0               80.0     295.0  2022        2      4
# 2                  70.0               82.0     251.0  2022        2      4
# 4078315           158.0              161.0     723.0  2022        1      3
# 4078316            86.0                NaN     319.0  2022        1      3
# 4078317            99.0                NaN     416.0  2022        1      3
#
#          DayofMonth  DayOfWeek Marketing_Airline_Network  \
# 0                 4          1                        UA
# 1                 4          1                        UA
# 2                 4          1                        UA
# 4078315           8          2                        UA
# 4078316          25          5                        UA
# 4078317           7          1                        UA
#
#         Operated_or_Branded_Code_Share_Partners  DOT_ID_Marketing_Airline  \
# 0                                  UA_CODESHARE                     19977
# 1                                  UA_CODESHARE                     19977
# 2                                  UA_CODESHARE                     19977
# 4078315                            UA_CODESHARE                     19977
# 4078316                            UA_CODESHARE                     19977
# 4078317                            UA_CODESHARE                     19977
#
#         IATA_Code_Marketing_Airline  Flight_Number_Marketing_Airline  \
# 0                                UA                             4301
# 1                                UA                             4299
# 2                                UA                             4298
# 4078315                          UA                             3413
# 4078316                          UA                             3450
# 4078317                          UA                             3585
#
#         Operating_Airline  DOT_ID_Operating_Airline  \
# 0               CommutAir                     20445
# 1               CommutAir                     20445
# 2               CommutAir                     20445
# 4078315  Republic Airways                     20452
# 4078316  Republic Airways                     20452
# 4078317  Republic Airways                     20452
#
#         IATA_Code_Operating_Airline Tail_Number  \
# 0                                C5      N21144
# 1                                C5      N16170
# 2                                C5      N21144
# 4078315                          YX      N733YX
# 4078316                          YX      N647RW
# 4078317                          YX      N648RW
#
#          Flight_Number_Operating_Airline  OriginAirportID  OriginAirportSeqID  \
# 0                                   4301            11921             1192102
# 1                                   4299            12206             1220605
# 2                                   4298            11413             1141307
# 4078315                             3413            10257             1025702
# 4078316                             3450            11618             1161802
# 4078317                             3585            11618             1161802
#
#          OriginCityMarketID            OriginCityName OriginState  \
# 0                     31921        Grand Junction, CO          CO
# 1                     32206  Harlingen/San Benito, TX          TX
# 2                     30285               Durango, CO          CO
# 4078315               30257                Albany, NY          NY
# 4078316               31703                Newark, NJ          NJ
# 4078317               31703                Newark, NJ          NJ
#
#          OriginStateFips OriginStateName  OriginWac  DestAirportID  \
# 0                      8        Colorado         82          11292
# 1                     48           Texas         74          12266
# 2                      8        Colorado         82          11292
# 4078315               36        New York         22          13930
# 4078316               34      New Jersey         21          14122
# 4078317               34      New Jersey         21          14492
#
#          DestAirportSeqID  DestCityMarketID        DestCityName DestState  \
# 0                 1129202             30325          Denver, CO        CO
# 1                 1226603             31453         Houston, TX        TX
# 2                 1129202             30325          Denver, CO        CO
# 4078315           1393007             30977         Chicago, IL        IL
# 4078316           1412202             30198      Pittsburgh, PA        PA
# 4078317           1449202             34492  Raleigh/Durham, NC        NC
#
#          DestStateFips   DestStateName  DestWac  DepDel15  \
# 0                    8        Colorado       82       0.0
# 1                   48           Texas       74       0.0
# 2                    8        Colorado       82       0.0
# 4078315             17        Illinois       41       1.0
# 4078316             42    Pennsylvania       23       1.0
# 4078317             37  North Carolina       36       0.0
#
#          DepartureDelayGroups DepTimeBlk  TaxiOut  WheelsOff  WheelsOn  \
# 0                        -1.0  1100-1159     17.0     1140.0    1220.0
# 1                        -1.0  0700-0759     16.0      744.0     839.0
# 2                        -1.0  1500-1559     21.0     1535.0    1622.0
# 4078315                  12.0  1700-1759     19.0     2337.0      52.0
# 4078316                   7.0  2100-2159     25.0     2347.0     933.0
# 4078317                  -1.0  1100-1159     13.0     1201.0    1552.0
#
#          TaxiIn  CRSArrTime  ArrDelay  ArrDel15  ArrivalDelayGroups  \
# 0           8.0        1245     -17.0       0.0                -2.0
# 1           9.0         849      -1.0       0.0                -1.0
# 2          14.0        1639      -3.0       0.0                -1.0
# 4078315     7.0        1838     381.0       1.0                12.0
# 4078316     6.0        2255       NaN       NaN                 NaN
# 4078317     4.0        1333       NaN       NaN                 NaN
#
#         ArrTimeBlk  DistanceGroup  DivAirportLandings
# 0        1200-1259              1                   0
# 1        0800-0859              2                   0
# 2        1600-1659              2                   0
# 4078315  1800-1859              3                   0
# 4078316  2200-2259              2                   1
# 4078317  1300-1359              2                   1

# %%
print('Total number of departure/origin cities:', df1.Origin.nunique())
print('==================================================')
print('Total number of arrivals/destinations cities:', df1.Dest.nunique())
print('==================================================')
# Out:
# Total number of departure/origin cities: 304
# ==================================================
# Total number of arrivals/destinations cities: 304
# ==================================================

# %%
df1.Diverted.value_counts()
# Out:
# False    3944916
# True       10210
# Name: Diverted, dtype: int64

# %%
DIVERTED_1 = df1['Diverted']==1

# %%
df1_DIV = df1[DIVERTED_1]
print(df1_DIV.shape)
# Out:
# (10210, 60)

# %%
df1_DIV.head()
# Out:
#       FlightDate                                    Airline      Origin  \
# 586   2022-04-03  Commutair Aka Champlain Enterprises, Inc.  Huntsville
# 765   2022-04-03                Air Wisconsin Airlines Corp     Chicago
# 1776  2022-04-01                Air Wisconsin Airlines Corp    Columbia
# 1845  2022-04-01                     Southwest Airlines Co.      Albany
# 1935  2022-04-01                     Southwest Airlines Co.     Atlanta
#
#               Dest  Diverted  CRSDepTime  DepTime  DepDelayMinutes  DepDelay  \
# 586        Houston      True         615    608.0              0.0      -7.0
# 765   White Plains      True        1415   1409.0              0.0      -6.0
# 1776     Chantilly      True        1445   1441.0              0.0      -4.0
# 1845       Orlando      True        1245   1316.0             31.0      31.0
# 1935      Sarasota      True        1015   1014.0              0.0      -1.0
#
#       ArrTime  ArrDelayMinutes  AirTime  CRSElapsedTime  ActualElapsedTime  \
# 586    1040.0              NaN      NaN           134.0                NaN
# 765    1928.0              NaN      NaN           134.0                NaN
# 1776   1719.0              NaN      NaN            87.0                NaN
# 1845   1901.0              NaN      NaN           175.0                NaN
# 1935   1436.0              NaN      NaN           100.0                NaN
#
#       Distance  Year  Quarter  Month  DayofMonth  DayOfWeek  \
# 586      595.0  2022        2      4           3          7
# 765      738.0  2022        2      4           3          7
# 1776     401.0  2022        2      4           1          5
# 1845    1073.0  2022        2      4           1          5
# 1935     444.0  2022        2      4           1          5
#
#      Marketing_Airline_Network Operated_or_Branded_Code_Share_Partners  \
# 586                         UA                            UA_CODESHARE
# 765                         UA                            UA_CODESHARE
# 1776                        UA                            UA_CODESHARE
# 1845                        WN                                      WN
# 1935                        WN                                      WN
#
#       DOT_ID_Marketing_Airline IATA_Code_Marketing_Airline  \
# 586                      19977                          UA
# 765                      19977                          UA
# 1776                     19977                          UA
# 1845                     19393                          WN
# 1935                     19393                          WN
#
#       Flight_Number_Marketing_Airline   Operating_Airline  \
# 586                              4228           CommutAir
# 765                              3766       Air Wisconsin
# 1776                             3763       Air Wisconsin
# 1845                              555  Southwest Airlines
# 1935                             1328  Southwest Airlines
#
#       DOT_ID_Operating_Airline IATA_Code_Operating_Airline Tail_Number  \
# 586                      20445                          C5      N27200
# 765                      20046                          ZW      N416AW
# 1776                     20046                          ZW      N441ZW
# 1845                     19393                          WN      N430WN
# 1935                     19393                          WN      N557WN
#
#       Flight_Number_Operating_Airline  OriginAirportID  OriginAirportSeqID  \
# 586                              4228            12217             1221702
# 765                              3766            13930             1393007
# 1776                             3763            10868             1086803
# 1845                              555            10257             1025702
# 1935                             1328            10397             1039707
#
#       OriginCityMarketID  OriginCityName OriginState  OriginStateFips  \
# 586                30255  Huntsville, AL          AL                1
# 765                30977     Chicago, IL          IL               17
# 1776               30868    Columbia, SC          SC               45
# 1845               30257      Albany, NY          NY               36
# 1935               30397     Atlanta, GA          GA               13
#
#      OriginStateName  OriginWac  DestAirportID  DestAirportSeqID  \
# 586          Alabama         51          12266           1226603
# 765         Illinois         41          12197           1219702
# 1776  South Carolina         37          12264           1226402
# 1845        New York         22          13204           1320402
# 1935         Georgia         34          14986           1498603
#
#       DestCityMarketID            DestCityName DestState  DestStateFips  \
# 586              31453             Houston, TX        TX             48
# 765              31703        White Plains, NY        NY             36
# 1776             30852          Washington, DC        VA             51
# 1845             31454             Orlando, FL        FL             12
# 1935             34986  Sarasota/Bradenton, FL        FL             12
#
#      DestStateName  DestWac  DepDel15  DepartureDelayGroups DepTimeBlk  \
# 586          Texas       74       0.0                  -1.0  0600-0659
# 765       New York       22       0.0                  -1.0  1400-1459
# 1776      Virginia       38       0.0                  -1.0  1400-1459
# 1845       Florida       33       1.0                   2.0  1200-1259
# 1935       Florida       33       0.0                  -1.0  1000-1059
#
#       TaxiOut  WheelsOff  WheelsOn  TaxiIn  CRSArrTime  ArrDelay  ArrDel15  \
# 586      14.0      622.0    1029.0    11.0         829       NaN       NaN
# 765      18.0     1427.0    1922.0     6.0        1729       NaN       NaN
# 1776      8.0     1449.0    1711.0     8.0        1612       NaN       NaN
# 1845     12.0     1328.0    1856.0     5.0        1540       NaN       NaN
# 1935     17.0     1031.0    1432.0     4.0        1155       NaN       NaN
#
#       ArrivalDelayGroups ArrTimeBlk  DistanceGroup  DivAirportLandings
# 586                  NaN  0800-0859              3                   1
# 765                  NaN  1700-1759              3                   1
# 1776                 NaN  1600-1659              2                   1
# 1845                 NaN  1500-1559              5                   1
# 1935                 NaN  1100-1159              2                   1

# %%
df1_DIV.ArrDelay.nunique()
# Out:
# 0

# %%
df1_DIV.ArrDelay.unique()
# Out:
# array([nan])

# %%
df1_DIV.AirTime.nunique()
# Out:
# 0

# %%
df1 = df1.drop(['Diverted'], axis=1)
df1.head(3)
# Out:
#    FlightDate                                    Airline          Origin  \
# 0  2022-04-04  Commutair Aka Champlain Enterprises, Inc.  Grand Junction
# 1  2022-04-04  Commutair Aka Champlain Enterprises, Inc.       Harlingen
# 2  2022-04-04  Commutair Aka Champlain Enterprises, Inc.         Durango
#
#       Dest  CRSDepTime  DepTime  DepDelayMinutes  DepDelay  ArrTime  \
# 0   Denver        1133   1123.0              0.0     -10.0   1228.0
# 1  Houston         732    728.0              0.0      -4.0    848.0
# 2   Denver        1529   1514.0              0.0     -15.0   1636.0
#
#    ArrDelayMinutes  AirTime  CRSElapsedTime  ActualElapsedTime  Distance  \
# 0              0.0     40.0            72.0               65.0     212.0
# 1              0.0     55.0            77.0               80.0     295.0
# 2              0.0     47.0            70.0               82.0     251.0
#
#    Year  Quarter  Month  DayofMonth  DayOfWeek Marketing_Airline_Network  \
# 0  2022        2      4           4          1                        UA
# 1  2022        2      4           4          1                        UA
# 2  2022        2      4           4          1                        UA
#
#   Operated_or_Branded_Code_Share_Partners  DOT_ID_Marketing_Airline  \
# 0                            UA_CODESHARE                     19977
# 1                            UA_CODESHARE                     19977
# 2                            UA_CODESHARE                     19977
#
#   IATA_Code_Marketing_Airline  Flight_Number_Marketing_Airline  \
# 0                          UA                             4301
# 1                          UA                             4299
# 2                          UA                             4298
#
#   Operating_Airline  DOT_ID_Operating_Airline IATA_Code_Operating_Airline  \
# 0         CommutAir                     20445                          C5
# 1         CommutAir                     20445                          C5
# 2         CommutAir                     20445                          C5
#
#   Tail_Number  Flight_Number_Operating_Airline  OriginAirportID  \
# 0      N21144                             4301            11921
# 1      N16170                             4299            12206
# 2      N21144                             4298            11413
#
#    OriginAirportSeqID  OriginCityMarketID            OriginCityName  \
# 0             1192102               31921        Grand Junction, CO
# 1             1220605               32206  Harlingen/San Benito, TX
# 2             1141307               30285               Durango, CO
#
#   OriginState  OriginStateFips OriginStateName  OriginWac  DestAirportID  \
# 0          CO                8        Colorado         82          11292
# 1          TX               48           Texas         74          12266
# 2          CO                8        Colorado         82          11292
#
#    DestAirportSeqID  DestCityMarketID DestCityName DestState  DestStateFips  \
# 0           1129202             30325   Denver, CO        CO              8
# 1           1226603             31453  Houston, TX        TX             48
# 2           1129202             30325   Denver, CO        CO              8
#
#   DestStateName  DestWac  DepDel15  DepartureDelayGroups DepTimeBlk  TaxiOut  \
# 0      Colorado       82       0.0                  -1.0  1100-1159     17.0
# 1         Texas       74       0.0                  -1.0  0700-0759     16.0
# 2      Colorado       82       0.0                  -1.0  1500-1559     21.0
#
#    WheelsOff  WheelsOn  TaxiIn  CRSArrTime  ArrDelay  ArrDel15  \
# 0     1140.0    1220.0     8.0        1245     -17.0       0.0
# 1      744.0     839.0     9.0         849      -1.0       0.0
# 2     1535.0    1622.0    14.0        1639      -3.0       0.0
#
#    ArrivalDelayGroups ArrTimeBlk  DistanceGroup  DivAirportLandings
# 0                -2.0  1200-1259              1                   0
# 1                -1.0  0800-0859              2                   0
# 2                -1.0  1600-1659              2                   0

# %%
df1.shape
# Out:
# (3955126, 59)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3955126 entries, 0 to 4078317
# Data columns (total 59 columns):
#  #   Column                                   Dtype
# ---  ------                                   -----
#  0   FlightDate                               object
#  1   Airline                                  object
#  2   Origin                                   object
#  3   Dest                                     object
#  4   CRSDepTime                               int64
#  5   DepTime                                  float64
#  6   DepDelayMinutes                          float64
#  7   DepDelay                                 float64
#  8   ArrTime                                  float64
#  9   ArrDelayMinutes                          float64
#  10  AirTime                                  float64
#  11  CRSElapsedTime                           float64
#  12  ActualElapsedTime                        float64
#  13  Distance                                 float64
#  14  Year                                     int64
#  15  Quarter                                  int64
#  16  Month                                    int64
#  17  DayofMonth                               int64
#  18  DayOfWeek                                int64
#  19  Marketing_Airline_Network                object
#  20  Operated_or_Branded_Code_Share_Partners  object
#  21  DOT_ID_Marketing_Airline                 int64
#  22  IATA_Code_Marketing_Airline              object
#  23  Flight_Number_Marketing_Airline          int64
#  24  Operating_Airline                        object
#  25  DOT_ID_Operating_Airline                 int64
#  26  IATA_Code_Operating_Airline              object
#  27  Tail_Number                              object
#  28  Flight_Number_Operating_Airline          int64
#  29  OriginAirportID                          int64
#  30  OriginAirportSeqID                       int64
#  31  OriginCityMarketID                       int64
#  32  OriginCityName                           object
#  33  OriginState                              object
#  34  OriginStateFips                          int64
#  35  OriginStateName                          object
#  36  OriginWac                                int64
#  37  DestAirportID                            int64
#  38  DestAirportSeqID                         int64
#  39  DestCityMarketID                         int64
#  40  DestCityName                             object
#  41  DestState                                object
#  42  DestStateFips                            int64
#  43  DestStateName                            object
#  44  DestWac                                  int64
#  45  DepDel15                                 float64
#  46  DepartureDelayGroups                     float64
#  47  DepTimeBlk                               object
#  48  TaxiOut                                  float64
#  49  WheelsOff                                float64
#  50  WheelsOn                                 float64
#  51  TaxiIn                                   float64
#  52  CRSArrTime                               int64
#  53  ArrDelay                                 float64
#  54  ArrDel15                                 float64
#  55  ArrivalDelayGroups                       float64
#  56  ArrTimeBlk                               object
#  57  DistanceGroup                            int64
#  58  DivAirportLandings                       int64
# dtypes: float64(18), int64(23), object(18)
# memory usage: 1.8+ GB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3955126 entries, 0 to 4078317
# Data columns (total 59 columns):
#  #   Column                                   Dtype
# ---  ------                                   -----
#  0   FlightDate                               object
#  1   Airline                                  object
#  2   Origin                                   object
#  3   Dest                                     object
#  4   CRSDepTime                               int64
#  5   DepTime                                  float64
#  6   DepDelayMinutes                          float64
#  7   DepDelay                                 float64
#  8   ArrTime                                  float64
#  9   ArrDelayMinutes                          float64
#  10  AirTime                                  float64
#  11  CRSElapsedTime                           float64
#  12  ActualElapsedTime                        float64
#  13  Distance                                 float64
#  14  Year                                     int64
#  15  Quarter                                  int64
#  16  Month                                    int64
#  17  DayofMonth                               int64
#  18  DayOfWeek                                int64
#  19  Marketing_Airline_Network                object
#  20  Operated_or_Branded_Code_Share_Partners  object
#  21  DOT_ID_Marketing_Airline                 int64
#  22  IATA_Code_Marketing_Airline              object
#  23  Flight_Number_Marketing_Airline          int64
#  24  Operating_Airline                        object
#  25  DOT_ID_Operating_Airline                 int64
#  26  IATA_Code_Operating_Airline              object
#  27  Tail_Number                              object
#  28  Flight_Number_Operating_Airline          int64
#  29  OriginAirportID                          int64
#  30  OriginAirportSeqID                       int64
#  31  OriginCityMarketID                       int64
#  32  OriginCityName                           object
#  33  OriginState                              object
#  34  OriginStateFips                          int64
#  35  OriginStateName                          object
#  36  OriginWac                                int64
#  37  DestAirportID                            int64
#  38  DestAirportSeqID                         int64
#  39  DestCityMarketID                         int64
#  40  DestCityName                             object
#  41  DestState                                object
#  42  DestStateFips                            int64
#  43  DestStateName                            object
#  44  DestWac                                  int64
#  45  DepDel15                                 float64
#  46  DepartureDelayGroups                     float64
#  47  DepTimeBlk                               object
#  48  TaxiOut                                  float64
#  49  WheelsOff                                float64
#  50  WheelsOn                                 float64
#  51  TaxiIn                                   float64
#  52  CRSArrTime                               int64
#  53  ArrDelay                                 float64
#  54  ArrDel15                                 float64
#  55  ArrivalDelayGroups                       float64
#  56  ArrTimeBlk                               object
#  57  DistanceGroup                            int64
#  58  DivAirportLandings                       int64
# dtypes: float64(18), int64(23), object(18)
# memory usage: 1.8+ GB

# %%
df1 = df1[['FlightDate','Operating_Airline','Flight_Number_Operating_Airline','Origin', 'Dest','CRSDepTime','DepTime','DepDelay','TaxiOut','WheelsOff','WheelsOn','TaxiIn','DepDel15','ArrTime','CRSArrTime','ArrDelay','CRSElapsedTime','ActualElapsedTime','AirTime','Distance']]
df1.head()
# Out:
#    FlightDate Operating_Airline  Flight_Number_Operating_Airline  \
# 0  2022-04-04         CommutAir                             4301
# 1  2022-04-04         CommutAir                             4299
# 2  2022-04-04         CommutAir                             4298
# 3  2022-04-04         CommutAir                             4296
# 4  2022-04-04         CommutAir                             4295
#
#            Origin             Dest  CRSDepTime  DepTime  DepDelay  TaxiOut  \
# 0  Grand Junction           Denver        1133   1123.0     -10.0     17.0
# 1       Harlingen          Houston         732    728.0      -4.0     16.0
# 2         Durango           Denver        1529   1514.0     -15.0     21.0
# 3         Houston  Gulfport-Biloxi        1435   1430.0      -5.0     16.0
# 4         Durango           Denver        1135   1135.0       0.0     19.0
#
#    WheelsOff  WheelsOn  TaxiIn  DepDel15  ArrTime  CRSArrTime  ArrDelay  \
# 0     1140.0    1220.0     8.0       0.0   1228.0        1245     -17.0
# 1      744.0     839.0     9.0       0.0    848.0         849      -1.0
# 2     1535.0    1622.0    14.0       0.0   1636.0        1639      -3.0
# 3     1446.0    1543.0     4.0       0.0   1547.0        1605     -18.0
# 4     1154.0    1243.0     8.0       0.0   1251.0        1245       6.0
#
#    CRSElapsedTime  ActualElapsedTime  AirTime  Distance
# 0            72.0               65.0     40.0     212.0
# 1            77.0               80.0     55.0     295.0
# 2            70.0               82.0     47.0     251.0
# 3            90.0               77.0     57.0     376.0
# 4            70.0               76.0     49.0     251.0

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3955126 entries, 0 to 4078317
# Data columns (total 20 columns):
#  #   Column                           Dtype
# ---  ------                           -----
#  0   FlightDate                       object
#  1   Operating_Airline                object
#  2   Flight_Number_Operating_Airline  int64
#  3   Origin                           object
#  4   Dest                             object
#  5   CRSDepTime                       int64
#  6   DepTime                          float64
#  7   DepDelay                         float64
#  8   TaxiOut                          float64
#  9   WheelsOff                        float64
#  10  WheelsOn                         float64
#  11  TaxiIn                           float64
#  12  DepDel15                         float64
#  13  ArrTime                          float64
#  14  CRSArrTime                       int64
#  15  ArrDelay                         float64
#  16  CRSElapsedTime                   float64
#  17  ActualElapsedTime                float64
#  18  AirTime                          float64
#  19  Distance                         float64
# dtypes: float64(13), int64(3), object(4)
# memory usage: 633.7+ MB

# %%
df1.drop(columns=['DepDel15','Flight_Number_Operating_Airline'],axis=1)
# Out:
#          FlightDate Operating_Airline          Origin             Dest  \
# 0        2022-04-04         CommutAir  Grand Junction           Denver
# 1        2022-04-04         CommutAir       Harlingen          Houston
# 2        2022-04-04         CommutAir         Durango           Denver
# 3        2022-04-04         CommutAir         Houston  Gulfport-Biloxi
# 4        2022-04-04         CommutAir         Durango           Denver
# ...             ...               ...             ...              ...
# 4078308  2022-03-31  Republic Airways        Key West           Newark
# 4078309  2022-03-31  Republic Airways       Cleveland           Newark
# 4078310  2022-03-31  Republic Airways       Chantilly       Pittsburgh
# 4078312  2022-03-19  Republic Airways          Newark          Memphis
# 4078315  2022-03-08  Republic Airways          Albany          Chicago
#
#          CRSDepTime  DepDelay  TaxiOut  WheelsOff  WheelsOn  TaxiIn  \
# 0                 2     -10.0     17.0          2         3     8.0
# 1                 2      -4.0     16.0          2         2     9.0
# 2                 3     -15.0     21.0          3         3    14.0
# 3                 3      -5.0     16.0          3         3     4.0
# 4                 2       0.0     19.0          2         3     8.0
# ...             ...       ...      ...        ...       ...     ...
# 4078308           3     216.0     19.0          4         4    12.0
# 4078309           3     223.0     14.0          4         4    10.0
# 4078310           3     195.0     14.0          4         4     5.0
# 4078312           4     154.0     14.0          4         1     5.0
# 4078315           3     378.0     19.0          4         1     7.0
#
#          CRSArrTime  ArrDelay  CRSElapsedTime  ActualElapsedTime  AirTime  \
# 0                 3     -17.0            72.0               65.0     40.0
# 1                 2      -1.0            77.0               80.0     55.0
# 2                 3      -3.0            70.0               82.0     47.0
# 3                 3     -18.0            90.0               77.0     57.0
# 4                 3       6.0            70.0               76.0     49.0
# ...             ...       ...             ...                ...      ...
# 4078308           4     207.0           192.0              183.0    152.0
# 4078309           3     201.0           111.0               89.0     65.0
# 4078310           4     180.0            71.0               56.0     37.0
# 4078312           4     135.0           182.0              163.0    144.0
# 4078315           4     381.0           158.0              161.0    135.0
#
#          Distance  DAY  MONTH MONTH_AB  FLIGHT_STATUS
# 0           212.0    4      4      Apr              0
# 1           295.0    4      4      Apr              0
# 2           251.0    4      4      Apr              0
# 3           376.0    4      4      Apr              0
# 4           251.0    4      4      Apr              1
# ...           ...  ...    ...      ...            ...
# 4078308    1196.0   31      3      Mar              1
# 4078309     404.0   31      3      Mar              1
# 4078310     182.0   31      3      Mar              1
# 4078312     946.0   19      3      Mar              1
# 4078315     723.0    8      3      Mar              1
#
# [3863219 rows x 20 columns]

# %%
df1.isna().sum()
# Out:
# FlightDate                         0
# Operating_Airline                  0
# Flight_Number_Operating_Airline    0
# Origin                             0
# Dest                               0
# CRSDepTime                         0
# DepDelay                           0
# TaxiOut                            0
# WheelsOff                          0
# WheelsOn                           0
# TaxiIn                             0
# DepDel15                           0
# CRSArrTime                         0
# ArrDelay                           0
# CRSElapsedTime                     0
# ActualElapsedTime                  0
# AirTime                            0
# Distance                           0
# DAY                                0
# MONTH                              0
# MONTH_AB                           0
# FLIGHT_STATUS                      0
# dtype: int64

# %%
print('Number of total missing values:', df1.isna().sum().sum())
print('df1 shape:', df1.shape)
# Out:
# Number of total missing values: 0
# df1 shape: (3863219, 22)

# %%
df_NaN = df1.loc[df1.isnull().any(axis=1)]
df_NaN.head(20)
# Out:
# Empty DataFrame
# Columns: [FlightDate, Operating_Airline, Flight_Number_Operating_Airline, Origin, Dest, CRSDepTime, DepDelay, TaxiOut, WheelsOff, WheelsOn, TaxiIn, DepDel15, CRSArrTime, ArrDelay, CRSElapsedTime, ActualElapsedTime, AirTime, Distance, DAY, MONTH, MONTH_AB, FLIGHT_STATUS]
# Index: []

# %%
df_NaN.shape
# Out:
# (91907, 18)

# %%
percentage_NaN = (len(df_NaN)*100)/len(df1)
print('Percentage of rows with at least 1 NaN value:', percentage_NaN)
# Out:
# Percentage of rows with at least 1 NaN value: 2.323743921179755

# %%
df1["DepDelay"] = df1["DepDelay"].fillna(0)
df1.isna().sum()
# Out:
# FlightDate                             0
# Operating_Airline                      0
# Flight_Number_Operating_Airline        0
# Origin                             44110
# Dest                               44129
# CRSDepTime                             0
# DepDelay                               0
# TaxiOut                                0
# WheelsOff                              0
# WheelsOn                            1050
# TaxiIn                              1050
# DepDel15                               0
# CRSArrTime                             0
# ArrDelay                           10210
# CRSElapsedTime                         0
# ActualElapsedTime                  10210
# AirTime                            10210
# Distance                               0
# dtype: int64

# %%
df1['TaxiIn'].fillna((df1['TaxiIn'].mean()), inplace=True)
df_NaN['TaxiIn'].fillna((df_NaN['TaxiIn'].mean()), inplace=True)

# %%
df_NaN.head()
# Out:
#      FlightDate Operating_Airline  Flight_Number_Operating_Airline  \
# 352  2022-04-03    GoJet Airlines                             4605
# 393  2022-04-03    GoJet Airlines                             4490
# 586  2022-04-03         CommutAir                             4228
# 765  2022-04-03     Air Wisconsin                             3766
# 876  2022-04-02    GoJet Airlines                             4605
#
#          Origin          Dest  CRSDepTime  DepDelay  TaxiOut  WheelsOff  \
# 352         NaN        Newark         607     -11.0     18.0      614.0
# 393      Newark           NaN        2235      25.0     22.0     2322.0
# 586  Huntsville       Houston         615      -7.0     14.0      622.0
# 765     Chicago  White Plains        1415      -6.0     18.0     1427.0
# 876         NaN        Newark         607     -13.0     33.0      627.0
#
#      WheelsOn  TaxiIn  DepDel15  CRSArrTime  ArrDelay  CRSElapsedTime  \
# 352     743.0     7.0       0.0         810     -20.0           123.0
# 393      30.0     5.0       1.0          16      19.0           101.0
# 586    1029.0    11.0       0.0         829       NaN           134.0
# 765    1922.0     6.0       0.0        1729       NaN           134.0
# 876     748.0     8.0       0.0         810     -14.0           123.0
#
#      ActualElapsedTime  AirTime  Distance
# 352              114.0     89.0     515.0
# 393               95.0     68.0     515.0
# 586                NaN      NaN     595.0
# 765                NaN      NaN     738.0
# 876              122.0     81.0     515.0

# %%
df1.TaxiIn.isna().sum()
# Out:
# 0

# %%
df1.isna().sum()
# Out:
# FlightDate                             0
# Operating_Airline                      0
# Flight_Number_Operating_Airline        0
# Origin                             44110
# Dest                               44129
# CRSDepTime                             0
# DepDelay                               0
# TaxiOut                                0
# WheelsOff                              0
# WheelsOn                            1050
# TaxiIn                                 0
# DepDel15                               0
# CRSArrTime                             0
# ArrDelay                           10210
# CRSElapsedTime                         0
# ActualElapsedTime                  10210
# AirTime                            10210
# Distance                               0
# dtype: int64

# %%
df1 = df1.dropna()

# %%
df1.shape
# Out:
# (3863219, 18)

# %%
df1.isna().sum()
# Out:
# FlightDate                         0
# Operating_Airline                  0
# Flight_Number_Operating_Airline    0
# Origin                             0
# Dest                               0
# CRSDepTime                         0
# DepDelay                           0
# TaxiOut                            0
# WheelsOff                          0
# WheelsOn                           0
# TaxiIn                             0
# DepDel15                           0
# CRSArrTime                         0
# ArrDelay                           0
# CRSElapsedTime                     0
# ActualElapsedTime                  0
# AirTime                            0
# Distance                           0
# dtype: int64

# %%
df1.head(2)
# Out:
#    FlightDate Operating_Airline  Flight_Number_Operating_Airline  \
# 0  2022-04-04         CommutAir                             4301
# 1  2022-04-04         CommutAir                             4299
#
#            Origin     Dest  CRSDepTime  DepDelay  TaxiOut  WheelsOff  \
# 0  Grand Junction   Denver        1133     -10.0     17.0     1140.0
# 1       Harlingen  Houston         732      -4.0     16.0      744.0
#
#    WheelsOn  TaxiIn  DepDel15  CRSArrTime  ArrDelay  CRSElapsedTime  \
# 0    1220.0     8.0       0.0        1245     -17.0            72.0
# 1     839.0     9.0       0.0         849      -1.0            77.0
#
#    ActualElapsedTime  AirTime  Distance
# 0               65.0     40.0     212.0
# 1               80.0     55.0     295.0

# %%
df1['CRSDepTime'] = np.ceil(df1['CRSDepTime']/600).apply(int)
df1['WheelsOff'] = np.ceil(df1['WheelsOff']/600).apply(int) 
df1['WheelsOn'] = np.ceil(df1['WheelsOn']/600).apply(int)

df1['CRSArrTime'] = np.ceil(df1['CRSArrTime']/600).apply(int)

# %%
df1.head()
# Out:
#    FlightDate Operating_Airline  Flight_Number_Operating_Airline  \
# 0  2022-04-04         CommutAir                             4301
# 1  2022-04-04         CommutAir                             4299
# 2  2022-04-04         CommutAir                             4298
# 3  2022-04-04         CommutAir                             4296
# 4  2022-04-04         CommutAir                             4295
#
#            Origin             Dest  CRSDepTime  DepDelay  TaxiOut  WheelsOff  \
# 0  Grand Junction           Denver           2     -10.0     17.0          2
# 1       Harlingen          Houston           2      -4.0     16.0          2
# 2         Durango           Denver           3     -15.0     21.0          3
# 3         Houston  Gulfport-Biloxi           3      -5.0     16.0          3
# 4         Durango           Denver           2       0.0     19.0          2
#
#    WheelsOn  TaxiIn  DepDel15  CRSArrTime  ArrDelay  CRSElapsedTime  \
# 0         3     8.0       0.0           3     -17.0            72.0
# 1         2     9.0       0.0           2      -1.0            77.0
# 2         3    14.0       0.0           3      -3.0            70.0
# 3         3     4.0       0.0           3     -18.0            90.0
# 4         3     8.0       0.0           3       6.0            70.0
#
#    ActualElapsedTime  AirTime  Distance
# 0               65.0     40.0     212.0
# 1               80.0     55.0     295.0
# 2               82.0     47.0     251.0
# 3               77.0     57.0     376.0
# 4               76.0     49.0     251.0

# %%
df1['DAY'] = pd.DatetimeIndex(df1['FlightDate']).day
df1['MONTH'] = pd.DatetimeIndex(df1['FlightDate']).month
df1.head(2)
# Out:
#    FlightDate Operating_Airline  Flight_Number_Operating_Airline  \
# 0  2022-04-04         CommutAir                             4301
# 1  2022-04-04         CommutAir                             4299
#
#            Origin     Dest  CRSDepTime  DepDelay  TaxiOut  WheelsOff  \
# 0  Grand Junction   Denver           2     -10.0     17.0          2
# 1       Harlingen  Houston           2      -4.0     16.0          2
#
#    WheelsOn  TaxiIn  DepDel15  CRSArrTime  ArrDelay  CRSElapsedTime  \
# 0         3     8.0       0.0           3     -17.0            72.0
# 1         2     9.0       0.0           2      -1.0            77.0
#
#    ActualElapsedTime  AirTime  Distance  DAY  MONTH
# 0               65.0     40.0     212.0    4      4
# 1               80.0     55.0     295.0    4      4

# %%
print('Maximum number of days in a month:', df1.DAY.nunique())
print('Total number of months:', df1.MONTH.nunique())
# Out:
# Maximum number of days in a month: 31
# Total number of months: 7

# %%
import calendar
df1['MONTH_AB'] = df1['MONTH'].apply(lambda x: calendar.month_abbr[x])

# %%
print('Months present in dataframe:', df1.MONTH.unique())
print('Months present in dataframe:', df1.MONTH_AB.unique())
# Out:
# Months present in dataframe: [4 2 7 5 6 1 3]
# Months present in dataframe: ['Apr' 'Feb' 'Jul' 'May' 'Jun' 'Jan' 'Mar']

# %%
status = []

for value in df1['ArrDelay']:
    if value < 0:
        status.append(0)
    else:
        status.append(1)
df1['FLIGHT_STATUS'] = status
df1.head(2)
# Out:
#    FlightDate Operating_Airline  Flight_Number_Operating_Airline  \
# 0  2022-04-04         CommutAir                             4301
# 1  2022-04-04         CommutAir                             4299
#
#            Origin     Dest  CRSDepTime  DepDelay  TaxiOut  WheelsOff  \
# 0  Grand Junction   Denver           2     -10.0     17.0          2
# 1       Harlingen  Houston           2      -4.0     16.0          2
#
#    WheelsOn  TaxiIn  DepDel15  CRSArrTime  ArrDelay  CRSElapsedTime  \
# 0         3     8.0       0.0           3     -17.0            72.0
# 1         2     9.0       0.0           2      -1.0            77.0
#
#    ActualElapsedTime  AirTime  Distance  DAY  MONTH MONTH_AB  FLIGHT_STATUS
# 0               65.0     40.0     212.0    4      4      Apr              0
# 1               80.0     55.0     295.0    4      4      Apr              0

# %%
df1.FLIGHT_STATUS.value_counts(normalize=True)
# Out:
# 0    0.604725
# 1    0.395275
# Name: FLIGHT_STATUS, dtype: float64

# %%
df1.to_csv('df1.csv')
